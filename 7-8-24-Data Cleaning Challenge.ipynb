# %% [markdown]
# # Business Problem

# %% [markdown]
# You are a data analyst working for a retail company. Your team has collected customer feedback data from multiple sources, including online reviews, surveys, and customer support interactions. Your task is to clean and prepare this data for analysis to identify common issues and areas for improvement.

# %% [markdown]
# # Loading Libraries

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import re
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Importing Data

# %%
retail_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data in Motion/7-8-24-Data Cleaning Challenge/original_customer_feedback.csv")
retail_df.head()
# Out:
#    review_id  customer_id feedback_source       feedback_text  rating  \
# 0          1          101   online_review      Great product!     5.0
# 1          2          102          survey  <b>Bad service</b>     1.0
# 2          3          103    support_call                 NaN     3.0
# 3          3          103    support_call                 NaN     3.0
# 4          4          104   online_review     Okay experience     4.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 3  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00

# %%
retail_data = retail_df.copy()
retail_data
# Out:
#    review_id  customer_id feedback_source  \
# 0          1          101   online_review
# 1          2          102          survey
# 2          3          103    support_call
# 3          3          103    support_call
# 4          4          104   online_review
# 5          5          105          survey
# 6          6          106    support_call
# 7          7          107   online_review
# 8          8          108          survey
# 9          9          109    support_call
#
#                                        feedback_text  rating  \
# 0                                     Great product!     5.0
# 1                                 <b>Bad service</b>     1.0
# 2                                                NaN     3.0
# 3                                                NaN     3.0
# 4                                    Okay experience     4.0
# 5                                         Good value     NaN
# 6  Terrible! <a href='http://example.com'>Read mo...     2.0
# 7                                            Not bad     4.0
# 8                         Excellent! Will buy again.     5.0
# 9                                                NaN     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 3  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5         invalid_date
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %%
retail_data.shape
# Out:
# (10, 6)

# %% [markdown]
# # 1. Remove duplicate rows based on the review_id column.

# %%
retail_data = retail_data.drop_duplicates(subset='review_id')

# %%
retail_data
# Out:
#    review_id  customer_id feedback_source  \
# 0          1          101   online_review
# 1          2          102          survey
# 2          3          103    support_call
# 4          4          104   online_review
# 5          5          105          survey
# 6          6          106    support_call
# 7          7          107   online_review
# 8          8          108          survey
# 9          9          109    support_call
#
#                                        feedback_text  rating  \
# 0                                     Great product!     5.0
# 1                                 <b>Bad service</b>     1.0
# 2                                                NaN     3.0
# 4                                    Okay experience     4.0
# 5                                         Good value     NaN
# 6  Terrible! <a href='http://example.com'>Read mo...     2.0
# 7                                            Not bad     4.0
# 8                         Excellent! Will buy again.     5.0
# 9                                                NaN     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5         invalid_date
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # 2. Fill missing feedback_text values with "No feedback provided".

# %%
retail_data.loc[retail_data['feedback_text'].isnull(), 'feedback_text'] = 'No feedback provided'

# %%
retail_data
# Out:
#    review_id  customer_id feedback_source  \
# 0          1          101   online_review
# 1          2          102          survey
# 2          3          103    support_call
# 4          4          104   online_review
# 5          5          105          survey
# 6          6          106    support_call
# 7          7          107   online_review
# 8          8          108          survey
# 9          9          109    support_call
#
#                                        feedback_text  rating  \
# 0                                     Great product!     5.0
# 1                                 <b>Bad service</b>     1.0
# 2                               No feedback provided     3.0
# 4                                    Okay experience     4.0
# 5                                         Good value     NaN
# 6  Terrible! <a href='http://example.com'>Read mo...     2.0
# 7                                            Not bad     4.0
# 8                         Excellent! Will buy again.     5.0
# 9                               No feedback provided     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5         invalid_date
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # 3. Fill missing rating values with the median rating.

# %%
rating_median = retail_data['rating'].median()
rating_median
# Out:
# 3.5

# %%
retail_data.loc[retail_data['rating'].isnull(), 'rating'] = rating_median
retail_data
# Out:
#    review_id  customer_id feedback_source  \
# 0          1          101   online_review
# 1          2          102          survey
# 2          3          103    support_call
# 4          4          104   online_review
# 5          5          105          survey
# 6          6          106    support_call
# 7          7          107   online_review
# 8          8          108          survey
# 9          9          109    support_call
#
#                                        feedback_text  rating  \
# 0                                     Great product!     5.0
# 1                                 <b>Bad service</b>     1.0
# 2                               No feedback provided     3.0
# 4                                    Okay experience     4.0
# 5                                         Good value     3.5
# 6  Terrible! <a href='http://example.com'>Read mo...     2.0
# 7                                            Not bad     4.0
# 8                         Excellent! Will buy again.     5.0
# 9                               No feedback provided     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5         invalid_date
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # 4. Remove HTML tags from the feedback_text column.

# %%
def remove_html(text):
    clean = re.sub(r'<[^>]*>', '', text)
    return clean

retail_data.loc[:, 'feedback_text'] = retail_data['feedback_text'].apply(remove_html)

retail_data
# Out:
#    review_id  customer_id feedback_source               feedback_text  rating  \
# 0          1          101   online_review              Great product!     5.0
# 1          2          102          survey                 Bad service     1.0
# 2          3          103    support_call        No feedback provided     3.0
# 4          4          104   online_review             Okay experience     4.0
# 5          5          105          survey                  Good value     3.5
# 6          6          106    support_call         Terrible! Read more     2.0
# 7          7          107   online_review                     Not bad     4.0
# 8          8          108          survey  Excellent! Will buy again.     5.0
# 9          9          109    support_call        No feedback provided     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1  2024-02-30 13:00:00
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5         invalid_date
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # 5. Convert timestamp values to a consistent datetime format.

# %%
retail_data.loc[:, 'timestamp'] = pd.to_datetime(retail_data['timestamp'], errors='coerce')
retail_data
# Out:
#    review_id  customer_id feedback_source               feedback_text  rating  \
# 0          1          101   online_review              Great product!     5.0
# 1          2          102          survey                 Bad service     1.0
# 2          3          103    support_call        No feedback provided     3.0
# 4          4          104   online_review             Okay experience     4.0
# 5          5          105          survey                  Good value     3.5
# 6          6          106    support_call         Terrible! Read more     2.0
# 7          7          107   online_review                     Not bad     4.0
# 8          8          108          survey  Excellent! Will buy again.     5.0
# 9          9          109    support_call        No feedback provided     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 1                  NaT
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 5                  NaT
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # 6. Remove rows with invalid dates.

# %%
retail_data = retail_data.dropna(subset=['timestamp'])
retail_data
# Out:
#    review_id  customer_id feedback_source               feedback_text  rating  \
# 0          1          101   online_review              Great product!     5.0
# 2          3          103    support_call        No feedback provided     3.0
# 4          4          104   online_review             Okay experience     4.0
# 6          6          106    support_call         Terrible! Read more     2.0
# 7          7          107   online_review                     Not bad     4.0
# 8          8          108          survey  Excellent! Will buy again.     5.0
# 9          9          109    support_call        No feedback provided     1.0
#
#              timestamp
# 0  2024-01-01 12:00:00
# 2  2024-03-15 14:00:00
# 4  2024-04-10 15:00:00
# 6  2024-06-20 16:00:00
# 7  2024-07-25 17:00:00
# 8  2024-08-30 18:00:00
# 9  2024-09-10 19:00:00

# %% [markdown]
# # Saving

# %%
# !jupyter nbconvert --to html '/content/drive/MyDrive/Colab Notebooks/Data in Motion/7-8-24-Data Cleaning Challenge/7-8-24-Data Cleaning Challenge.ipynb'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Data in Motion/7-8-24-Data Cleaning Challenge/7-8-24-Data Cleaning Challenge.ipynb to html
# [NbConvertApp] Writing 678743 bytes to /content/drive/MyDrive/Colab Notebooks/Data in Motion/7-8-24-Data Cleaning Challenge/7-8-24-Data Cleaning Challenge.html
